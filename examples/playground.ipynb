# %%
from mixedbread_parsing_haystack.converter import MixedbreadFileConverter

# %%
converter = MixedbreadFileConverter()

# %%
document = converter.run(paths=["./data"])
# Out:
# Converting files to Haystack Documents: 1it [00:51, 51.86s/it]

# %%
document
# Out:
# {'documents': [Document(id=363b85ba-bbaf-41c0-aac1-5dd6ead212d0_0, content: 'Image Summary: The image shows a stylized, cartoon-like orange duckling character enclosed in a blac...', meta: {'_bboxes': [{'type': 'picture', 'bbox': [439.208740234375, 1361.3675537109375, 1388.155517578125, 2009.0667724609375], 'page': 9}, {'type': 'table', 'bbox': [452.04852294921875, 952.1882934570312, 1360.00390625, 1318.014892578125], 'page': 9}, {'type': 'table', 'bbox': [1375.025634765625, 883.4760131835938, 2281.0703125, 1588.46435546875], 'page': 9}, {'type': 'text', 'bbox': [428.4215393066406, 2135.739013671875, 2129.200439453125, 2408.964111328125], 'page': 9}, {'type': 'page-footer', 'bbox': [1242.524658203125, 3092.96875, 1310.7796630859375, 3134.925537109375], 'page': 9}]}),
#   Document(id=363b85ba-bbaf-41c0-aac1-5dd6ead212d0_1, content: 'Here is what Docling delivers today:
# ...
